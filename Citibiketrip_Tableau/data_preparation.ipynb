# %%
# Import setup
import pandas as pd

# %%
# Create a list containing all the files for 2022 Jersey City data
files = ['JC-202301-citibike-tripdata.csv',
         'JC-202302-citibike-tripdata.csv',
         'JC-202303-citibike-tripdata.csv',
         'JC-202304-citibike-tripdata.csv',
         'JC-202305-citibike-tripdata.csv',
         'JC-202306-citibike-tripdata.csv',
         'JC-202307-citibike-tripdata.csv',
         'JC-202308-citibike-tripdata.csv',
         'JC-202309-citibike-tripdata.csv',
         'JC-202310-citibike-tripdata.csv',
         'JC-202311-citibike-tripdata.csv',
         'JC-202312-citibike-tripdata.csv']

# %%
# Create an empty dataframe to store all data
citibike_df = pd.DataFrame()

# %%
# Loop through the list of files and concatonate all data to the dataframe
for file in files:
    data = pd.read_csv(file) 
    citibike_df = pd.concat([citibike_df, data], axis=0)

# %%
# Show the dataframe
citibike_df
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      0905B18B365C9D20   classic_bike  2023-01-28 09:18:10
# 1      B4F0562B05CB5404  electric_bike  2023-01-23 20:10:12
# 2      5ABF032895F5D87E   classic_bike  2023-01-29 15:27:04
# 3      E7E1F9C53976D2F9   classic_bike  2023-01-24 18:35:08
# 4      323165780CA0734B   classic_bike  2023-01-21 20:44:09
# ...                 ...            ...                  ...
# 58675  7E862701EE7A6A03   classic_bike  2023-12-20 17:55:41
# 58676  DFAF91AB91BE25DB   classic_bike  2023-12-13 14:36:43
# 58677  AEE7B49E6EDFAE6F   classic_bike  2023-12-18 16:40:00
# 58678  A38E98956AD72EFB   classic_bike  2023-12-02 13:42:51
# 58679  F16E0B969D877368   classic_bike  2023-12-19 16:30:13
#
#                   ended_at                        start_station_name  \
# 0      2023-01-28 09:28:52  Hoboken Terminal - Hudson St & Hudson Pl
# 1      2023-01-23 20:18:27  Hoboken Terminal - Hudson St & Hudson Pl
# ...

# %%
# Store the dataframe as CSV file
citibike_df.to_csv('citibike2023jc_data.csv', index=False)
